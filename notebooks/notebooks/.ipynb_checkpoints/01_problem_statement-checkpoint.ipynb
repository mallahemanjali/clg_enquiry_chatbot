# %% [markdown]
# # Phase 1: Problem Statement Definition
#
# **Project Title:** AI Chatbot for College Enquiry System
# **Student Name:** [MALLA HEMANJALI]
# **Domain:** [CSE(AI&ML)]

# %% [markdown]
# ## 1. Business / Problem Statement
#
# In most engineering colleges and universities, students, parents, and prospective candidates face significant challenges in obtaining timely and accurate information. Common queries include admission procedures, fee structures, course details, scholarships, hostel facilities, placements, faculty information, etc.
#
# Traditional enquiry systems (visiting office, phone calls, emails) are time-consuming, staff-dependent, and not available 24/7. This results in poor user experience, delayed responses, and increased workload on administrative staff.

# %% [markdown]
# ## 2. Objective of the Project
#
# The main objective of this project is to develop an **intelligent AI-powered Chatbot** using Natural Language Processing (NLP) that can:
#
# - Understand users' natural language questions
# - Identify the intent behind the query
# - Provide instant, accurate, and relevant responses
# - Work 24/7 without human intervention
# - Improve the overall student and parent experience

# %% [markdown]
# ## 3. Target Variable
#
# - **Target Variable:** `tag` (Intent)
# - This is the class/label that the model will predict.
# - Examples of tags: `greeting`, `admission`, `fees`, `courses`, `placement`, `scholarship`, `hostel`, `library`, `contact`, `faculty`, etc.
#
# It is a **Multi-Class Classification** problem.

# %% [markdown]
# ## 4. Expected Outcome
#
# - A fully functional **web-based Chatbot** built using Streamlit
# - Model accuracy **greater than 95%**
# - User-friendly interface with chat functionality
# - Complete Machine Learning pipeline (EDA, Preprocessing, Model Building, Deployment)
# - Professional documentation and GitHub repository
# - Ready for real-world deployment

# %% [markdown]
# ## 5. Type of Machine Learning Problem
#
# **This project belongs to:**
# **Natural Language Processing (NLP)**
# **→ Specifically: Text Classification (Intent Classification)**

# %%
# Phase 1: Problem Statement Definition

print("✅ Phase 1 Completed")
print("Project Title: AI Chatbot for College Enquiry System")
print("Domain: Education")
print("Problem Type: NLP - Intent Classification")
print("Target Variable: tag (Intent)")
print("Expected Accuracy: > 95%")
# Out:
# ✅ Phase 1 Completed
# Project Title: AI Chatbot for College Enquiry System
# Domain: Education
# Problem Type: NLP - Intent Classification
# Target Variable: tag (Intent)
# Expected Accuracy: > 95%

# %% [markdown]
# ## Benefits of the Project
#
# - 24/7 availability
# - Instant responses
# - Reduced workload on college staff
# - Better student satisfaction
# - Scalable and maintainable system
